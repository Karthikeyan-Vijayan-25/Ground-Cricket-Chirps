# %% [markdown]
# # Assignment5

# %% [markdown]
#  **Ground Cricket Chirps**
#
# In The Song of Insects (1948) by George W. Pierce, Pierce mechanically measured the frequency (the number of wing vibrations per second) of chirps (or pulses of sound) made by a striped ground cricket, at various ground temperatures. Since crickets are ectotherms (cold-blooded), the rate of their physiological processes and their overall metabolism are influenced by temperature. Consequently, there is reason to believe that temperature would have a profound effect on aspects of their behavior, such as chirp frequency.
#
# In general, it was found that crickets did not sing at temperatures colder than 60º F. or warmer than 100º F.

# %% [markdown]
# ### Tasks
#
# 1. Find the linear regression equation for this data.
# 2. Chart the original data and the equation on the chart.
# 3. Find the equation's $R^2$ score (use the `.score` method) to determine whether the
# equation is a good fit for this data. (0.8 and greater is considered a strong correlation.)
# 4. Extrapolate data:  If the ground temperature reached 95, then at what approximate rate would you expect the crickets to be chirping?
# 5. Interpolate data:  With a listening device, you discovered that on a particular morning the crickets were chirping at a rate of 18 chirps per second.  What was the approximate ground temperature that morning?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
ground_cricket_data = {"Chirps/Second": [20.0, 16.0, 19.8, 18.4, 17.1, 15.5, 14.7,
                                         15.7, 15.4, 16.3, 15.0, 17.2, 16.0, 17.0,
                                         14.4],
                       "Ground Temperature": [88.6, 71.6, 93.3, 84.3, 80.6, 75.2, 69.7,
                                              71.6, 69.4, 83.3, 79.6, 82.6, 80.6, 83.5,
                                              76.3]}
df = pd.DataFrame(ground_cricket_data)
df
# Out:
#     Chirps/Second  Ground Temperature
# 0            20.0                88.6
# 1            16.0                71.6
# 2            19.8                93.3
# 3            18.4                84.3
# 4            17.1                80.6
# 5            15.5                75.2
# 6            14.7                69.7
# 7            15.7                71.6
# 8            15.4                69.4
# 9            16.3                83.3
# 10           15.0                79.6
# 11           17.2                82.6
# 12           16.0                80.6
# 13           17.0                83.5
# 14           14.4                76.3

# %%
X = df[['Ground Temperature']]

Y = df[['Chirps/Second']]

# %%
plt.figure( figsize = (4,4))
plt.scatter (X,Y)
plt.show()

# %%
reg = LinearRegression()
reg.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Task 1
# Find the linear regression equation for this data.

# %%
# Linear Regression Equation: y=mx+c


print ("The linear regression equation for this data is, y=", reg.coef_[0], "*x+", reg.intercept_)
# Out:
# The linear regression equation for this data is, y= [0.20299973] *x+ [0.45931465]

# %% [markdown]
# ## Task 2
# Chart the original data and the equation on the chart.

# %%
y_pred = reg.predict(X)

# %%
plt.figure( figsize = (8,6))

plt.scatter (X, Y, label="Actual Data")
plt.scatter (X, y_pred, label="Predicted Data")
plt.legend()
plt.title('Ground Cricket Chirps Per Second by Ground Temperature (˚F)')
plt.xlabel('Ground Temperature')
plt.ylabel('Chirps/Second')
# Out:
# Text(0, 0.5, 'Chirps/Second')

# %% [markdown]
# ## Task 3
# Find the equation's  𝑅2  score (use the .score method) to determine whether the equation is a good fit for this data. (0.8 and greater is considered a strong correlation.)

# %%
from sklearn.metrics import r2_score

# %%
print("the equation's 𝑅2 score is", r2_score(Y,y_pred))

R2_Score = r2_score(Y,y_pred)

if R2_Score >= 0.8:
  print("It's a good model")
else:
  print("It's not a good model")
# Out:
# the equation's 𝑅2 score is 0.6922946529146998
# It's not a good model

# %% [markdown]
# ## Task 4
# Extrapolate data: If the ground temperature reached 95, then at what approximate rate would you expect the crickets to be chirping?

# %%
print('When the temperature is 95˚F, the approximate rate of chirps/sec is:',reg.predict([[95]]))
# Out:
# When the temperature is 95˚F, the approximate rate of chirps/sec is: [[19.74428913]]
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"

# %% [markdown]
# ## Task 5
# Interpolate data: With a listening device, you discovered that on a particular morning the crickets were chirping at a rate of 18 chirps per second. What was the approximate ground temperature that morning?

# %% [markdown]
# ### The Linear Regression Equation For This Data is y = [0.20299973] * x + [0.45931465]
#
# ### Therefore ,
#
# ### x = ( y - [0.45931465] ) / 0.20299973

# %%
temp = (18- reg.intercept_)/reg.coef_[0]

print("The expected temperature,if the crickets were chirping at a rate of 18 chirps per second is", temp,'˚F')
# Out:
# The expected temperature,if the crickets were chirping at a rate of 18 chirps per second is [86.40743135] ˚F
